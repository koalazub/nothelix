# %% [markdown]
# # Multi-plot capture stress test
#
# Four cells exercising per-expression plot capture. Execute each in turn and confirm every declared plot renders inline.

# %%
using Plots
plot(rand(10))
plot(rand(10), rand(10))
scatter(rand(10), rand(10))

# %%
let
    a = plot(rand(10))
    b = plot(rand(10).^2)
    display(a)
    display(b)
end

# %%
if true
    plot(rand(10))
end

# %%
plot(rand(10))
